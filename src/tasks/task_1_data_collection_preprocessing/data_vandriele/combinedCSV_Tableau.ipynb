# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import pandas as pd
# !pip install plotly.express
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
os.chdir('/content/drive/My Drive/projeto_sãopaulo_subway/final_dataset/conbinedcsv')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combinar todos os arquivos da lista
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#exportar para csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('/content/drive/My Drive/projeto_sãopaulo_subway/final_dataset/conbinedcsv/combined_csv.csv')

# %%
df
# Out:
#             month  line          station     dpea
# 0      2021-01-01    15       São Mateus  11000.0
# 1      2021-01-01    15  Fazenda da Juta   2000.0
# 2      2021-01-01    15        Sapopemba   5000.0
# 3      2021-01-01    15  Jardim Planalto   2000.0
# 4      2021-01-01    15       Vila União   3000.0
# ...           ...   ...              ...      ...
# 15715  2023-12-01     1       São Judas       0.0
# 15716  2023-12-01     1       Conceição       0.0
# 15717  2023-12-01     1        Jabaquara      0.0
# 15718  2023-12-01     1               Sé      0.0
# 15719  2023-12-01     1         Ana Rosa      0.0
#
# [15720 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15720 entries, 0 to 15719
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    15720 non-null  object
#  1   line     15720 non-null  int64
#  2   station  15720 non-null  object
#  3   dpea     15720 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 491.4+ KB

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (15720, 4)

# %%
lines = df["line"]
fig = px.bar(df, y='dpea', x='month',text_auto='.2s')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Plot the time series with different colors for each line

fig = px.bar(df,x='month' , y='dpea',barmode="group", facet_col="line",title="DPEA per line")
# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["dpea"]
