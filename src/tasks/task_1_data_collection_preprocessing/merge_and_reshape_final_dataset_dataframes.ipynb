# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
line_numbers = ['01','02','03','04','05','15' ]

# %%
# checking if the time series size and range for each metro line file
date_dict={}
for line in line_numbers:
    df = pd.read_csv(f'final_datasets/l{line}_pes_complete.csv')
    date_dict[line] = pd.to_datetime(df['month'].unique())
    print(f'{line},{date_dict[line].size},{date_dict[line][0]},{date_dict[line][-1]}')
# Out:
# 01,36,2021-01-01 00:00:00,2023-12-01 00:00:00
# 02,36,2021-01-01 00:00:00,2023-12-01 00:00:00
# 03,36,2021-01-01 00:00:00,2023-12-01 00:00:00
# 04,28,2021-01-01 00:00:00,2023-04-01 00:00:00
# 05,28,2021-01-01 00:00:00,2023-04-01 00:00:00
# 15,36,2021-01-01 00:00:00,2023-12-01 00:00:00

# %% [markdown]
# Some files have dates beyond April 2023, like lines 1, 2, 3, and 15, although there is no valid data for those (the values are filled with zeros).
# Hence, I will limit the data between January 2021 and April 2023.

# %%
datelimit = datetime(2023,4,1) 
for line in line_numbers:
    df = pd.read_csv(f'final_datasets/l{line}_pes_complete.csv')
    df['month'] = pd.to_datetime(df['month']) 
    # Pivot the DataFrame
    df = df.loc[df['month']<=datelimit].pivot(index='month', columns='station', values='dpea')
    df.columns = pd.MultiIndex.from_product([[int(line)], df.columns])
    df.columns.names = ['Line', 'Station']
    df.to_csv(f'final_datasets/reshaped_l{line}_pes_complete.csv')
    if 'new_df' in globals():
        new_df = new_df.merge(df, left_index=True, right_index=True, how='outer')
    else:
        new_df = df
new_df.to_csv(f'final_datasets/merged_reshaped_pes_complete.csv')

# %%
new_df
# Out:
# Line             1                                                             \
# Station    Ana Rosa Armênia  Carandiru  Conceição  Jabaquara Japão-Liberdade
# month
# 2021-01-01  40000.0  14000.0     6000.0    15000.0   46000.0          12000.0
# 2021-02-01  43000.0  15000.0     6000.0    16000.0   48000.0          12000.0
# 2021-03-01  35000.0  12000.0     5000.0    12000.0   40000.0           9000.0
# 2021-04-01  33000.0  12000.0     5000.0    12000.0   39000.0           9000.0
# 2021-05-01  39000.0  14000.0     6000.0    14000.0   45000.0          11000.0
# 2021-06-01  41000.0  14000.0     6000.0    15000.0   46000.0          12000.0
# 2021-07-01  42000.0  15000.0     6000.0    15000.0   48000.0          12000.0
# 2021-08-01  47000.0  15000.0     7000.0    16000.0   51000.0          13000.0
# 2021-09-01  51000.0  16000.0     7000.0    18000.0   55000.0          14000.0
# 2021-10-01  53000.0  17000.0     8000.0    19000.0   57000.0          15000.0
# 2021-11-01  57000.0  18000.0     9000.0    20000.0   61000.0          16000.0
# 2021-12-01  53000.0  16000.0     8000.0    19000.0   59000.0          16000.0
# 2022-01-01  46000.0  15000.0     7000.0    16000.0   53000.0          14000.0
# 2022-02-01  57000.0  17000.0     9000.0    20000.0   58000.0          16000.0
# 2022-03-01  65000.0  19000.0    10000.0    22000.0   63000.0          18000.0
# 2022-04-01  68000.0  21000.0    10000.0    24000.0   66000.0          20000.0
# 2022-05-01  68000.0  21000.0    10000.0    23000.0   66000.0          19000.0
# 2022-06-01  66000.0  20000.0    10000.0    22000.0   64000.0          18000.0
# 2022-07-01  62000.0  19000.0     9000.0    21000.0   64000.0          20000.0
# 2022-08-01  70000.0  20000.0    10000.0    23000.0   66000.0          20000.0
# 2022-09-01  71000.0  21000.0    11000.0    24000.0   67000.0          20000.0
# 2022-10-01  71000.0  20000.0    10000.0    24000.0   69000.0          21000.0
# 2022-11-01  72000.0  21000.0    11000.0    25000.0   69000.0          20000.0
# 2022-12-01  60000.0  17000.0     9000.0    21000.0   64000.0          20000.0
# 2023-01-01  59000.0  17000.0     8000.0    20000.0   63000.0          19000.0
# 2023-02-01  70000.0  20000.0    10000.0    24000.0   66000.0          20000.0
# 2023-03-01  75000.0  21000.0    11000.0    26000.0   70000.0          22000.0
# 2023-04-01  75000.0  21000.0    11000.0    26000.0   72000.0          22000.0
#
# Line                                                                         \
# Station    Jardim São Paulo-Ayrton Senna       Luz Parada Inglesa   Paraíso
# month
# 2021-01-01                        6000.0   70000.0          7000.0  49000.0
# 2021-02-01                        6000.0   74000.0          7000.0  53000.0
# 2021-03-01                        5000.0   57000.0          6000.0  43000.0
# 2021-04-01                        4000.0   58000.0          5000.0  42000.0
# 2021-05-01                        5000.0   68000.0          6000.0  48000.0
# 2021-06-01                        6000.0   69000.0          7000.0  50000.0
# 2021-07-01                        6000.0   69000.0          7000.0  52000.0
# 2021-08-01                        7000.0   74000.0          8000.0  58000.0
# 2021-09-01                        7000.0   89000.0          8000.0  62000.0
# 2021-10-01                        8000.0   96000.0          9000.0  65000.0
# 2021-11-01                        9000.0  106000.0          9000.0  69000.0
# 2021-12-01                        8000.0   99000.0          9000.0  65000.0
# 2022-01-01                        7000.0   86000.0          7000.0  57000.0
# 2022-02-01                        8000.0  100000.0          9000.0  69000.0
# 2022-03-01                       10000.0  108000.0         10000.0  80000.0
# 2022-04-01                       10000.0  114000.0         11000.0  84000.0
# 2022-05-01                       10000.0  115000.0         11000.0  84000.0
# 2022-06-01                       10000.0  111000.0         11000.0  81000.0
# 2022-07-01                        9000.0  111000.0         10000.0  77000.0
# 2022-08-01                       10000.0  117000.0         11000.0  87000.0
# 2022-09-01                       11000.0  119000.0         11000.0  89000.0
# 2022-10-01                       11000.0  127000.0         12000.0  89000.0
# 2022-11-01                       11000.0  126000.0         12000.0  90000.0
# 2022-12-01                        9000.0  113000.0         10000.0  75000.0
# 2023-01-01                        8000.0  108000.0          9000.0  73000.0
# 2023-02-01                       11000.0  122000.0         11000.0  87000.0
# 2023-03-01                       11000.0  127000.0         12000.0  94000.0
# 2023-04-01                       11000.0  130000.0         12000.0  94000.0
#
# Line        ...              15                                           \
# Station     ... Fazenda da Juta Jardim Colonial Jardim Planalto Oratório
# month       ...
# 2021-01-01  ...          2000.0             0.0          2000.0   3000.0
# 2021-02-01  ...          2000.0             0.0          3000.0   3000.0
# 2021-03-01  ...          2000.0             0.0          2000.0   3000.0
# 2021-04-01  ...          2000.0             0.0          2000.0   3000.0
# 2021-05-01  ...          2000.0             0.0          2000.0   3000.0
# 2021-06-01  ...          2000.0             0.0          3000.0   3000.0
# 2021-07-01  ...          2000.0             0.0          3000.0   4000.0
# 2021-08-01  ...          3000.0             0.0          3000.0   4000.0
# 2021-09-01  ...          3000.0             0.0          3000.0   4000.0
# 2021-10-01  ...          3000.0             0.0          3000.0   4000.0
# 2021-11-01  ...          3000.0             0.0          3000.0   5000.0
# 2021-12-01  ...          3000.0             0.0          3000.0   4000.0
# 2022-01-01  ...          3000.0             0.0          3000.0   4000.0
# 2022-02-01  ...          3000.0          1000.0          3000.0   5000.0
# 2022-03-01  ...          4000.0          3000.0          4000.0   5000.0
# 2022-04-01  ...          4000.0          4000.0          4000.0   5000.0
# 2022-05-01  ...          4000.0          4000.0          4000.0   5000.0
# 2022-06-01  ...          4000.0          4000.0          4000.0   5000.0
# 2022-07-01  ...          4000.0          4000.0          4000.0   5000.0
# 2022-08-01  ...          4000.0          5000.0          4000.0   6000.0
# 2022-09-01  ...          4000.0          5000.0          4000.0   6000.0
# 2022-10-01  ...          4000.0          5000.0          4000.0   5000.0
# 2022-11-01  ...          4000.0          5000.0          4000.0   6000.0
# 2022-12-01  ...          4000.0          5000.0          4000.0   5000.0
# 2023-01-01  ...          3000.0          5000.0          4000.0   5000.0
# 2023-02-01  ...          4000.0          5000.0          4000.0   6000.0
# 2023-03-01  ...          4000.0          6000.0          4000.0   6000.0
# 2023-04-01  ...          4000.0          6000.0          4000.0   6000.0
#
# Line                                                                  \
# Station    Sapopemba São Lucas São Mateus Vila Prudente Vila Tolstói
# month
# 2021-01-01    5000.0    3000.0    11000.0       31000.0       3000.0
# 2021-02-01    5000.0    3000.0    12000.0       31000.0       3000.0
# 2021-03-01    4000.0    2000.0    11000.0       27000.0       2000.0
# 2021-04-01    4000.0    2000.0    10000.0       26000.0       2000.0
# 2021-05-01    5000.0    3000.0    12000.0       29000.0       3000.0
# 2021-06-01    5000.0    3000.0    12000.0       28000.0       3000.0
# 2021-07-01    5000.0    3000.0    13000.0       35000.0       3000.0
# 2021-08-01    6000.0    3000.0    14000.0       38000.0       3000.0
# 2021-09-01    6000.0    4000.0    14000.0       41000.0       3000.0
# 2021-10-01    6000.0    4000.0    15000.0       42000.0       4000.0
# 2021-11-01    7000.0    4000.0    16000.0       45000.0       4000.0
# 2021-12-01    6000.0    4000.0    15000.0       41000.0       4000.0
# 2022-01-01    5000.0    3000.0    13000.0       38000.0       3000.0
# 2022-02-01    6000.0    4000.0    16000.0       45000.0       4000.0
# 2022-03-01    7000.0    4000.0    16000.0       49000.0       4000.0
# 2022-04-01    7000.0    5000.0    16000.0       51000.0       4000.0
# 2022-05-01    7000.0    5000.0    15000.0       51000.0       5000.0
# 2022-06-01    7000.0    5000.0    15000.0       50000.0       5000.0
# 2022-07-01    7000.0    4000.0    15000.0       49000.0       4000.0
# 2022-08-01    8000.0    5000.0    16000.0       51000.0       5000.0
# 2022-09-01    8000.0    5000.0    16000.0       53000.0       5000.0
# 2022-10-01    8000.0    5000.0    16000.0       52000.0       5000.0
# 2022-11-01    8000.0    5000.0    17000.0       54000.0       5000.0
# 2022-12-01    7000.0    4000.0    15000.0       43000.0       4000.0
# 2023-01-01    7000.0    4000.0    14000.0       46000.0       4000.0
# 2023-02-01    8000.0    5000.0    16000.0       55000.0       5000.0
# 2023-03-01    8000.0    5000.0    16000.0       57000.0       5000.0
# 2023-04-01    8000.0    5000.0    16000.0       60000.0       5000.0
#
# Line
# Station    Vila União
# month
# 2021-01-01     3000.0
# 2021-02-01     4000.0
# 2021-03-01     3000.0
# 2021-04-01     3000.0
# 2021-05-01     3000.0
# 2021-06-01     3000.0
# 2021-07-01     4000.0
# 2021-08-01     4000.0
# 2021-09-01     4000.0
# 2021-10-01     4000.0
# 2021-11-01     5000.0
# 2021-12-01     4000.0
# 2022-01-01     4000.0
# 2022-02-01     4000.0
# 2022-03-01     5000.0
# 2022-04-01     5000.0
# 2022-05-01     5000.0
# 2022-06-01     5000.0
# 2022-07-01     5000.0
# 2022-08-01     5000.0
# 2022-09-01     5000.0
# 2022-10-01     5000.0
# 2022-11-01     5000.0
# 2022-12-01     5000.0
# 2023-01-01     4000.0
# 2023-02-01     5000.0
# 2023-03-01     5000.0
# 2023-04-01     5000.0
#
# [28 rows x 94 columns]

# %%
new_df.columns
# Out:
# MultiIndex([( 1,                         'Ana Rosa'),
#             ( 1,                         'Armênia '),
#             ( 1,                       'Carandiru '),
#             ( 1,                       'Conceição '),
#             ( 1,                        'Jabaquara'),
#             ( 1,                 'Japão-Liberdade '),
#             ( 1,    'Jardim São Paulo-Ayrton Senna'),
#             ( 1,                              'Luz'),
#             ( 1,                  'Parada Inglesa '),
#             ( 1,                          'Paraíso'),
#             ( 1,                'Portuguesa-Tietê '),
#             ( 1,                 'Praça da Árvore '),
#             ( 1,                       'Santa Cruz'),
#             ( 1,                         'Santana '),
#             ( 1,                           'Saúde '),
#             ( 1,                        'São Bento'),
#             ( 1,                     'São Joaquim '),
#             ( 1,                       'São Judas '),
#             ( 1,                               'Sé'),
#             ( 1,                      'Tiradentes '),
#             ( 1,                        'Tucuruvi '),
#             ( 1,                       'Vergueiro '),
#             ( 1,                    'Vila Mariana '),
#             ( 2,                'Alto do Ipiranga '),
#             ( 2,                         'Ana Rosa'),
#             ( 2,                      'Brigadeiro '),
#             ( 2,                  'Chácara Klabin '),
#             ( 2,                        'Clínicas '),
#             ( 2,                       'Consolação'),
#             ( 2,                          'Paraíso'),
#             ( 2,                           'Sacomã'),
#             ( 2,               'Santos-Imigrantes '),
#             ( 2, 'Santuário N.S. de Fátima-Sumaré '),
#             ( 2,                      'Tamanduateí'),
#             ( 2,                    'Trianon-Masp '),
#             ( 2,                    'Vila Madalena'),
#             ( 2,                    'Vila Prudente'),
#             ( 3,                       'Anhangabaú'),
#             ( 3,                      'Artur Alvim'),
#             ( 3,                           'Belém '),
#             ( 3,                   'Bresser-Moóca '),
#             ( 3,                             'Brás'),
#             ( 3,                          'Carrão '),
#             ( 3,             'Corinthians-Itaquera'),
#             ( 3,           'Guilhermina-Esperança '),
#             ( 3,                'Marechal Deodoro '),
#             ( 3,            'Palmeiras-Barra Funda'),
#             ( 3,                       'Patriarca '),
#             ( 3,                        'Pedro II '),
#             ( 3,                           'Penha '),
#             ( 3,                        'República'),
#             ( 3,                   'Santa Cecília '),
#             ( 3,                               'Sé'),
#             ( 3,                          'Tatuapé'),
#             ( 3,                    'Vila Matilde '),
#             ( 4,                          'Butantã'),
#             ( 4,                       'Faria Lima'),
#             ( 4,                'Fradique Coutinho'),
#             ( 4,         'Higienópolis - Mackenzie'),
#             ( 4,                              'Luz'),
#             ( 4,                     'Oscar Freire'),
#             ( 4,                         'Paulista'),
#             ( 4,                        'Pinheiros'),
#             ( 4,                        'República'),
#             ( 4,              'São Paulo - Morumbi'),
#             ( 4,                       'Vila Sônia'),
#             ( 5,                  'AACD - Servidor'),
#             ( 5,                  'Adolfo Pinheiro'),
#             ( 5,                'Alto da Boa Vista'),
#             ( 5,                       'Borba Gato'),
#             ( 5,                         'Brooklin'),
#             ( 5,                       'Campo Belo'),
#             ( 5,                      'Campo Limpo'),
#             ( 5,                    'Capão Redondo'),
#             ( 5,                   'Chácara Klabin'),
#             ( 5,                       'Eucaliptos'),
#             ( 5,                 'Giovanni Gronchi'),
#             ( 5,               'Hospital São Paulo'),
#             ( 5,                      'Largo Treze'),
#             ( 5,                            'Moema'),
#             ( 5,                       'Santa Cruz'),
#             ( 5,                      'Santo Amaro'),
#             ( 5,                 'Vila das Belezas'),
#             (15,                    'Camilo Haddad'),
#             (15,                  'Fazenda da Juta'),
#             (15,                  'Jardim Colonial'),
#             (15,                  'Jardim Planalto'),
#             (15,                         'Oratório'),
#             (15,                        'Sapopemba'),
#             (15,                        'São Lucas'),
#             (15,                       'São Mateus'),
#             (15,                    'Vila Prudente'),
#             (15,                     'Vila Tolstói'),
#             (15,                       'Vila União')],
#            names=['Line', 'Station'])
