# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
pasta = os.getcwd()

# %%
#os.chdir(pasta + '/Entrada de Passageiros por Estação/')

url_2021 = "https://transparencia.metrosp.com.br/sites/default/files/Entrada%20de%20Passageiros%20por%20Esta%C3%A7%C3%A3o%20-%20M%C3%A9dia%20Dias%20%C3%9Ateis%20-%202021.csv"
url_2022 = "https://transparencia.metrosp.com.br/sites/default/files/Entrada%20de%20Passageiros%20por%20Esta%C3%A7%C3%A3o%20-%20M%C3%A9dia%20dias%20%C3%9Ateis%20-%202022_0.csv"
url_2023 = "https://transparencia.metrosp.com.br/sites/default/files/Entrada%20de%20Passageiros%20por%20Esta%C3%A7%C3%A3o%20-%20M%C3%A9dia%20Dias%20%C3%9Ateis%20-%202023_1.csv"



#    Passenger Entry by Station 2021
demanda_estacao_1_2021 = pd.read_csv(url_2021,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[:23,0:14]
demanda_estacao_1_2021.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_1_2021['Year'] = '2021'
demanda_estacao_1_2021['Line'] = '1_Blue'


demanda_estacao_2_2021 = pd.read_csv(url_2021,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[30:44,0:14]
demanda_estacao_2_2021.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_2_2021['Year'] = '2021'
demanda_estacao_2_2021['Line'] = '2_Green'

demanda_estacao_3_2021 = pd.read_csv(url_2021,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[51:69,0:14]
demanda_estacao_3_2021.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_3_2021['Year'] = '2021'
demanda_estacao_3_2021['Line'] = '3_Red'

demanda_estacao_15_2021 = pd.read_csv(url_2021,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[75:86,0:14]
demanda_estacao_15_2021.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_15_2021['Year'] = '2021'
demanda_estacao_15_2021['Line'] = '15_Silver'

demanda_estacao = pd.concat([demanda_estacao_1_2021, demanda_estacao_2_2021,demanda_estacao_3_2021,demanda_estacao_15_2021], ignore_index=True) 

#   Passenger Entry by Station 2022

demanda_estacao_1_2022 = pd.read_csv(url_2022,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[:23,0:14]
demanda_estacao_1_2022.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_1_2022['Year'] = '2022'
demanda_estacao_1_2022['Line'] = '1_Blue'

demanda_estacao_2_2022 = pd.read_csv(url_2022,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[30:44,0:14]
demanda_estacao_2_2022.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_2_2022['Year'] = '2022'
demanda_estacao_2_2022['Line'] = '2_Green'


demanda_estacao_3_2022 = pd.read_csv(url_2022,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[51:69,0:14]
demanda_estacao_3_2022.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_3_2022['Year'] = '2022'
demanda_estacao_3_2022['Line'] = '3_Red'

demanda_estacao_15_2022 = pd.read_csv(url_2022,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[75:86,0:14]
demanda_estacao_15_2022.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_15_2022['Year'] = '2022'
demanda_estacao_15_2022['Line'] = '15_Silver'

demanda_estacao = pd.concat([demanda_estacao,demanda_estacao_1_2022, demanda_estacao_2_2022,demanda_estacao_3_2022,demanda_estacao_15_2022], ignore_index=True) 

#    Passenger Entry by Station 2023

demanda_estacao_1_2023 = pd.read_csv(url_2023,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[:23,0:14]
demanda_estacao_1_2023.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_1_2023['Year'] = '2023'
demanda_estacao_1_2023['Line'] = '1_Blue'

demanda_estacao_2_2023 = pd.read_csv(url_2023,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[30:44,0:14]
demanda_estacao_2_2023.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_2_2023['Year'] = '2023'
demanda_estacao_2_2023['Line'] = '2_Green'


demanda_estacao_3_2023 = pd.read_csv(url_2023,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[51:69,0:14]
demanda_estacao_3_2023.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_3_2023['Year'] = '2023'
demanda_estacao_3_2023['Line'] = '3_Red'

demanda_estacao_15_2023 = pd.read_csv(url_2023,encoding='latin-1',sep=';',skiprows=lambda x: x in range(0, 5),thousands='.').iloc[75:86,0:14]
demanda_estacao_15_2023.columns = ['Station','January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean']
demanda_estacao_15_2023['Year'] = '2023'
demanda_estacao_15_2023['Line'] = '15_Silver'

demanda_estacao = pd.concat([demanda_estacao,demanda_estacao_1_2023, demanda_estacao_2_2023,demanda_estacao_3_2023,demanda_estacao_15_2023], ignore_index=True) 

demanda_estacao.to_csv("entry_by_station.csv")

display(demanda_estacao)
# Out:
#               Station January February March April  May June July August  \
# 0           Jabaquara      46       48    40    39   45   46   48     51
# 1          Conceição       15       16    12    12   14   15   15     16
# 2          São Judas        9        9     7     7    8    9    9     10
# 3              Saúde       16       17    13    13   15   16   16     18
# 4    Praça da Árvore        9       10     8     8    9    9   10     11
# ..                ...     ...      ...   ...   ...  ...  ...  ...    ...
# 193   Jardim Planalto      4        4     4     4   NaN  NaN  NaN    NaN
# 194         Sapopemba      7        8     8     8   NaN  NaN  NaN    NaN
# 195   Fazenda da Juta      3        4     4     4   NaN  NaN  NaN    NaN
# 196        São Mateus     14       16    16    16   NaN  NaN  NaN    NaN
# 197   Jardim Colonial      5        5     6     6   NaN  NaN  NaN    NaN
#
#     September October November December  Mean  Year       Line
# ...

# %%
fig, ax = plt.subplots(nrows=2,ncols=1,figsize=(15,7),gridspec_kw={'height_ratios': [1,1]})

demanda_estacao_1_2021[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean','Year']] = demanda_estacao_1_2021[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean','Year']].astype(float)
demanda_estacao_1_2022[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean','Year']] = demanda_estacao_1_2021[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December','Mean','Year']].astype(float)

ax[0].bar(demanda_estacao_1_2021.Station, demanda_estacao_1_2021.Mean)
ax[1].bar(demanda_estacao_1_2022.Station, demanda_estacao_1_2022.Mean)

ax[0].tick_params(axis='x',labelrotation=90)

ax[1].tick_params(axis='x',labelrotation=90)


plt.show()
